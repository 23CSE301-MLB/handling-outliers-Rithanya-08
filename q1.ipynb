# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df= pd.read_csv("heart_failure_clinical_records_dataset.csv")

# Preview
df.head(5)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
sns.boxplot(df["age"])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(df["creatinine_phosphokinase"])
# Out:
# <Axes: ylabel='creatinine_phosphokinase'>

# %%
sns.boxplot(df["platelets"])
# Out:
# <Axes: ylabel='platelets'>

# %%
sns.boxplot(df["serum_sodium"])
# Out:
# <Axes: ylabel='serum_sodium'>

# %%
from scipy import stats

Q1 = df['serum_sodium'].quantile(0.25)
Q3 = df['serum_sodium'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['serum_sodium'] >= lower_bound) 
& (df['serum_sodium'] <= upper_bound)]
print(df.shape)
# Out:
# (295, 13)

# %%
Q1 = df['platelets'].quantile(0.25)
Q3 = df['platelets'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['platelets'] >= lower_bound) 
& (df['platelets'] <= 600000)]
print(df.shape)
# Out:
# (285, 13)

# %%
Q1 = df['creatinine_phosphokinase'].quantile(0.25)
Q3 = df['creatinine_phosphokinase'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['creatinine_phosphokinase'] >= lower_bound) 
& (df['creatinine_phosphokinase'] <= 3500)]
print(df.shape)
# Out:
# (278, 13)

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  278.000000  278.000000                278.000000  278.000000
# mean    60.914871    0.442446                446.651079    0.410072
# std     11.817079    0.497572                522.756175    0.492733
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                113.000000    0.000000
# 50%     60.000000    0.000000                234.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               2794.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         278.000000           278.000000     278.000000
# mean           38.172662             0.366906  263445.599496
# std            11.818072             0.482830   80458.649619
# min            14.000000             0.000000  105000.000000
# ...

# %%
df.head(5)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 5  90.0        1                        47         0                 40
# 6  75.0        1                       246         0                 15
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1   265000.0               1.9           130    1
# 2                    0   162000.0               1.3           129    1
# 3                    0   210000.0               1.9           137    1
# 5                    1   204000.0               2.1           132    1
# 6                    0   127000.0               1.2           137    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 2        1     7            1
# ...

# %%
sorted = df.sort_values("age")

# %%
sorted.head(10)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 269  40.0        0                       582         1                 35
# 248  40.0        0                       624         0                 35
# 232  40.0        1                       129         0                 35
# 242  40.0        0                        90         0                 35
# 206  40.0        1                       101         0                 40
# 180  40.0        0                       478         1                 30
# 189  40.0        0                       244         0                 45
# 70   41.0        0                       148         0                 40
# 92   42.0        0                       582         0                 60
# 77   42.0        0                       102         1                 40
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 269                    0  222000.00              1.00           132    1
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df["creatinine_phosphokinase"] = scaler.fit_transform(df[["creatinine_phosphokinase"]])

# %%
df["age"] = scaler.fit_transform(df[["age"]])

# %%
df["ejection_fraction"] = scaler.fit_transform(df[["ejection_fraction"]])

# %%
df["platelets"] = scaler.fit_transform(df[["platelets"]])

# %%
df["serum_creatinine"] = scaler.fit_transform(df[["serum_creatinine"]])

# %%
df["serum_sodium"] = scaler.fit_transform(df[["serum_sodium"]])

# %%
df.head(10)
# Out:
#          age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0   0.636364        0                  0.201732         0           0.090909
# 2   0.454545        0                  0.044388         0           0.090909
# 3   0.181818        1                  0.031757         0           0.090909
# 5   0.909091        1                  0.008661         0           0.393939
# 6   0.636364        1                  0.080476         0           0.015152
# 7   0.363636        1                  0.105377         1           0.696970
# 8   0.454545        0                  0.048358         0           0.772727
# 9   0.727273        1                  0.036088         0           0.318182
# 10  0.636364        1                  0.020931         0           0.363636
# 11  0.400000        0                  0.075063         0           0.166667
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df["time"] = scaler.fit_transform(df[["time"]])

# %%
df.head(10)
# Out:
#          age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0   0.636364        0                  0.201732         0           0.090909
# 2   0.454545        0                  0.044388         0           0.090909
# 3   0.181818        1                  0.031757         0           0.090909
# 5   0.909091        1                  0.008661         0           0.393939
# 6   0.636364        1                  0.080476         0           0.015152
# 7   0.363636        1                  0.105377         1           0.696970
# 8   0.454545        0                  0.048358         0           0.772727
# 9   0.727273        1                  0.036088         0           0.318182
# 10  0.636364        1                  0.020931         0           0.363636
# 11  0.400000        0                  0.075063         0           0.166667
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.iloc[0,4]
# Out:
# np.float64(0.09090909090909091)

# %%
df.loc[0,'age']
# Out:
# np.float64(0.6363636363636362)

# %%
df.groupby("age").mean()
# Out:
#            anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# age
# 0.000000  0.285714                  0.107594  0.285714           0.339827
# 0.018182  0.000000                  0.045110  0.000000           0.393939
# 0.036364  0.333333                  0.060748  0.333333           0.343434
# 0.054545  1.000000                  0.120895  0.000000           0.545455
# 0.072727  0.000000                  0.111873  1.000000           0.318182
# 0.090909  0.250000                  0.295899  0.500000           0.380682
# 0.109091  0.500000                  0.173944  0.000000           0.356061
# 0.127273  0.000000                  0.201732  0.000000           0.166667
# 0.145455  1.000000                  0.038975  1.000000           0.242424
# 0.163636  0.500000                  0.164020  0.250000           0.299242
# 0.181818  0.423077                  0.172432  0.423077           0.319930
# 0.200000  0.250000                  0.228257  0.500000           0.356061
# ...

# %%
df.to_csv("output.csv",index=False)

# %%
sns.lineplot(x="age",y="platelets",data=df)
# Out:
# <Axes: xlabel='age', ylabel='platelets'>

# %%
df.head()
# Out:
#         age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  0.636364        0                  0.201732         0           0.090909
# 2  0.454545        0                  0.044388         0           0.090909
# 3  0.181818        1                  0.031757         0           0.090909
# 5  0.909091        1                  0.008661         0           0.393939
# 6  0.636364        1                  0.080476         0           0.015152
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1   0.365297          0.157303      0.217391    1
# 2                    0   0.130137          0.089888      0.173913    1
# 3                    0   0.239726          0.157303      0.521739    1
# 5                    1   0.226027          0.179775      0.304348    1
# 6                    0   0.050228          0.078652      0.521739    1
#
#    smoking      time  DEATH_EVENT
# 0        0  0.000000            1
# ...

# %%
# Line chart: age vs. ejection_fraction
plt.plot(df['age'], df['ejection_fraction'], 'o')
plt.xlabel('Age')
plt.ylabel('Ejection Fraction')
plt.title('Age vs. Ejection Fraction')
plt.show()

# %%
df['sex'].value_counts().plot(kind='bar', title='Patients by Sex')
plt.show()

# %%
df['DEATH_EVENT'].value_counts().plot.pie(autopct='%1.1f%%', title='Survival Status')
plt.show()

# %%
sns.histplot(df['age'], bins=20, kde=True)
plt.title("Age Distribution")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Feature Correlation Matrix")
plt.show()

# %%
# Question 2

# %%
df = pd.read_csv("credit_scoring_eng.csv")

# %%
df.head()
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1   -8437.673028         42       masters degree             0
# 1         1   -4024.803754         36  secondary education             1
# 2         0   -5623.422610         33  Secondary Education             1
# 3         3   -4124.747207         32  secondary education             1
# 4         0  340266.072047         53  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  \
# 0            married                 0      F    employee     0
# 1            married                 0      F    employee     0
# 2            married                 0      M    employee     0
# 3            married                 0      M    employee     0
# 4  civil partnership                 1      F     retiree     0
#
#     total_income                  purpose
# 0  253875.639453    purchase of the house
# 1  112080.014102             car purchase
# ...

# %%
df["income_type"].unique()
# Out:
# array(['employee', 'retiree', 'partner', 'civil servant', 'unempoyed',
#        'entrepreneur', 'student', 'paternity / maternity leave'],
#       dtype=object)

# %%
df["family_status"].unique()
# Out:
# array(['married', 'civil partnership', 'widow / widower', 'divorced',
#        'unmarried'], dtype=object)

# %%
df["education"].unique()
# Out:
# array(['masters degree', 'secondary education', 'Secondary Education',
#        'SECONDARY EDUCATION', 'MASTERS DEGREE', 'bachelor degree',
#        'primary education', 'Masters Degree', 'BACHELOR DEGREE',
#        'Bachelor Degree', 'PRIMARY EDUCATION', 'Primary Education',
#        'Academic Degree', 'ACADEMIC DEGREE', 'academic degree'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %%
df.describe()
# Out:
#            children  days_employed     dob_years  education_id  \
# count  21525.000000   19351.000000  21525.000000  21525.000000
# mean       0.538908   63046.497661     43.293380      0.817236
# std        1.381587  140827.311974     12.574584      0.548138
# min       -1.000000  -18388.949901      0.000000      0.000000
# 25%        0.000000   -2747.423625     33.000000      1.000000
# 50%        0.000000   -1203.369529     42.000000      1.000000
# 75%        1.000000    -291.095954     53.000000      1.000000
# max       20.000000  401755.400475     75.000000      4.000000
#
#        family_status_id          debt  total_income
# count      21525.000000  21525.000000  1.935100e+04
# mean           0.972544      0.080883  1.674223e+05
# std            1.420324      0.272661  1.029716e+05
# min            0.000000      0.000000  2.066726e+04
# 25%            0.000000      0.000000  1.030532e+05
# 50%            0.000000      0.000000  1.450179e+05
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        children  days_employed  dob_years            education  education_id  \
# 0             1   -8437.673028         42       masters degree             0
# 1             1   -4024.803754         36  secondary education             1
# 2             0   -5623.422610         33  Secondary Education             1
# 3             3   -4124.747207         32  secondary education             1
# 4             0  340266.072047         53  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21520         1   -4529.316663         43  secondary education             1
# 21521         0  343937.404131         67  secondary education             1
# 21522         1   -2113.346888         38  secondary education             1
# 21523         3   -3112.481705         38  secondary education             1
# 21524         2   -1984.507589         40  secondary education             1
#
# ...

# %%
df.sort_values(by='total_income', ascending=False).head()
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 12412         0   -1477.438114         44       masters degree             0
# 19606         1   -2577.664662         39       masters degree             0
# 9169          1   -5248.554336         35  secondary education             1
# 20809         0   -4719.273476         61  secondary education             1
# 17178         0   -5734.127087         42       masters degree             0
#
#            family_status  family_status_id gender income_type  debt  \
# 12412            married                 0      M     partner     0
# 19606            married                 0      M     partner     1
# 9169   civil partnership                 1      M    employee     0
# 20809          unmarried                 4      F    employee     0
# 17178  civil partnership                 1      M     partner     0
#
#        total_income                              purpose
# ...

# %%
# View nulls
df.isnull().sum()

# Fill or drop
df.fillna(df.mean(numeric_only=True), inplace=True) 
df.fillna("Unknown", inplace=True)  # Categorical columns
df.isnull().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %%
features = ['total_income', 'dob_years']
for col in features:
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
df.head()
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1   -8437.673028         42       masters degree             0
# 1         1   -4024.803754         36  secondary education             1
# 2         0   -5623.422610         33  Secondary Education             1
# 3         3   -4124.747207         32  secondary education             1
# 4         0  340266.072047         53  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  \
# 0            married                 0      F    employee     0
# 1            married                 0      F    employee     0
# 2            married                 0      M    employee     0
# 3            married                 0      M    employee     0
# 4  civil partnership                 1      F     retiree     0
#
#     total_income                  purpose
# 0  253875.639453    purchase of the house
# 1  112080.014102             car purchase
# ...

# %%
for col in features:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    outliers = ((df[col] < (Q1 - 1.5 * IQR)) | (df[col] > (Q3 + 1.5 * IQR))).sum()
    print(f"{col}: {outliers} outliers")
# Out:
# total_income: 818 outliers
# dob_years: 101 outliers

# %%
Q1 = df['total_income'].quantile(0.25)
Q3 = df['total_income'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df['total_income'] = np.where(df['total_income'] < lower, lower,
                np.where(df['total_income'] > upper, upper, df['total_income']))
df.head()
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1   -8437.673028         42       masters degree             0
# 1         1   -4024.803754         36  secondary education             1
# 2         0   -5623.422610         33  Secondary Education             1
# 3         3   -4124.747207         32  secondary education             1
# 4         0  340266.072047         53  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  \
# 0            married                 0      F    employee     0
# 1            married                 0      F    employee     0
# 2            married                 0      M    employee     0
# 3            married                 0      M    employee     0
# 4  civil partnership                 1      F     retiree     0
#
#     total_income                  purpose
# 0  253875.639453    purchase of the house
# 1  112080.014102             car purchase
# ...

# %%
for col in features:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    outliers = ((df[col] < (Q1 - 1.5 * IQR)) | (df[col] > (Q3 + 1.5 * IQR))).sum()
    print(f"{col}: {outliers} outliers")
# Out:
# total_income: 0 outliers
# dob_years: 0 outliers

# %%
Q1 = df["dob_years"].quantile(0.25)
Q3 = df["dob_years"].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
df = df[(df["dob_years"] >= lower) & (df["dob_years"] <= upper)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df.loc[:, "dob_years"] = scaler.fit_transform(df[["dob_years"]])

# %%
df.head()
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1   -8437.673028   0.410714       masters degree             0
# 1         1   -4024.803754   0.303571  secondary education             1
# 2         0   -5623.422610   0.250000  Secondary Education             1
# 3         3   -4124.747207   0.232143  secondary education             1
# 4         0  340266.072047   0.607143  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  \
# 0            married                 0      F    employee     0
# 1            married                 0      F    employee     0
# 2            married                 0      M    employee     0
# 3            married                 0      M    employee     0
# 4  civil partnership                 1      F     retiree     0
#
#     total_income                  purpose
# 0  253875.639453    purchase of the house
# 1  112080.014102             car purchase
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df.loc[:, "days_employed"] = scaler.fit_transform(df[["days_employed"]])

# %%
df.head()
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1      -0.535313   0.410714       masters degree             0
# 1         1      -0.502261   0.303571  secondary education             1
# 2         0      -0.514234   0.250000  Secondary Education             1
# 3         3      -0.503009   0.232143  secondary education             1
# 4         0       2.076420   0.607143  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  \
# 0            married                 0      F    employee     0
# 1            married                 0      F    employee     0
# 2            married                 0      M    employee     0
# 3            married                 0      M    employee     0
# 4  civil partnership                 1      F     retiree     0
#
#     total_income                  purpose
# 0  253875.639453    purchase of the house
# 1  112080.014102             car purchase
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df.loc[:, "total_income"] = scaler.fit_transform(df[["total_income"]])

# %%
df.head()
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1      -0.535313   0.410714       masters degree             0
# 1         1      -0.502261   0.303571  secondary education             1
# 2         0      -0.514234   0.250000  Secondary Education             1
# 3         3      -0.503009   0.232143  secondary education             1
# 4         0       2.076420   0.607143  secondary education             1
#
#        family_status  family_status_id gender income_type  debt  total_income  \
# 0            married                 0      F    employee     0      0.761207
# 1            married                 0      F    employee     0      0.298377
# 2            married                 0      M    employee     0      0.408722
# 3            married                 0      M    employee     0      0.806097
# 4  civil partnership                 1      F     retiree     0      0.450274
#
#                    purpose
# 0    purchase of the house
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df.loc[:,"gender"] = encoder.fit_transform(df["gender"])

# %%
df.head()
# Out:
#    children  days_employed  dob_years            education  education_id  \
# 0         1      -0.535313   0.410714       masters degree             0
# 1         1      -0.502261   0.303571  secondary education             1
# 2         0      -0.514234   0.250000  Secondary Education             1
# 3         3      -0.503009   0.232143  secondary education             1
# 4         0       2.076420   0.607143  secondary education             1
#
#        family_status  family_status_id  gender income_type  debt  \
# 0            married                 0       0    employee     0
# 1            married                 0       0    employee     0
# 2            married                 0       1    employee     0
# 3            married                 0       1    employee     0
# 4  civil partnership                 1       0     retiree     0
#
#    total_income                  purpose
# 0      0.761207    purchase of the house
# 1      0.298377             car purchase
# ...

# %%
# Bar plot of credit status
df['children'].value_counts().plot(kind='bar', title='Children')
plt.show()

# %%
# Pie chart of employment length
df['days_employed'].value_counts().plot.pie(autopct='%1.1f%%', title='Employment Length')
plt.show()

# %%
# Distribution plot: years employed
sns.histplot(df['days_employed'], bins=20, kde=True)
plt.title("days Employed Distribution")
plt.show()
